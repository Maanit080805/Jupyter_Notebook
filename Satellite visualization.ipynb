# %%
#magic command, #creating an environment for matplotlib,#to make notebook interactive to see images...
# %matplotlib inline 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread

# %%
# from skimage import data
photo_data = imread('sd-3layers.jpg')
photo_data.shape #height becomes row, width becomes column, 3 is basically the 3 primary colours..
#type(photo_data) #it will give ndarray
# Out:
# (3725, 4797, 3)

# %%
plt.figure(figsize=(15,15)) #iches is their unit
plt.imshow(photo_data)

# %%
photo_data[0,3000]
# Out:
# array([192,   8,   0], dtype=uint8)

# %%
photo_data.max()
# Out:
# 255

# %%
photo_data.min()
# Out:
# 0

# %%
#size is an atrribute so we have not put bracket there
photo_data.size
# Out:
# 53606475

# %%
photo_data.mean()
# Out:
# 75.8299354508947

# %%
photo_data[:250,2500:3500,0].mean()
# Out:
# 196.75082
